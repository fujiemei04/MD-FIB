# %%
import pandas as pd
# %matplotlib inline
import chardet
import pandas
from pandas import plotting
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import decomposition
from sklearn import datasets
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.cluster import KMeans

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif

pandas.set_option('display.max_columns', None)
pandas.set_option('display.expand_frame_repr', False)
pandas.set_option('max_colwidth', None)
pandas.set_option('display.precision', 3)

plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_31856\1668778658.py:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %% [markdown]
# ### Position of the player near or away from the basket

# %%
#Figure out what the correct encoding should be and read in the file to a DataFrame
with open("nba_data.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000000))

# check what the character encoding might be
print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# ### Reading dataset

# %%
data = pandas.read_csv('nba_data.csv', sep=';', encoding='Windows-1252')
data
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  0.8  2.1  0.359  2.9   6.1  0.468  0.486  1.1  1.8  0.595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  0.0  0.0  0.000  2.8   5.0  0.548  0.547  1.4  2.6  0.543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  0.0  0.1  0.000  7.3  12.9  0.562  0.557  4.6  6.1  0.753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  0.2  1.5  0.125  1.5   2.6  0.560  0.424  0.6  1.0  0.625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  0.3  1.0  0.304  5.1   8.8  0.578  0.566  1.9  2.2  0.873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...   ...    ...    ...  ...  ...    ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  0.7  1.7  0.395  1.9   3.9  0.495  0.524  0.5  1.0  0.481  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  3.1  8.0  0.382  6.3  12.3  0.512  0.536  6.6  7.3  0.904  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526  0.0  0.2  0.091  2.3   4.2  0.547  0.528  0.7  1.1  0.623  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  0.0  0.1  0.000  1.9   3.2  0.593  0.567  1.4  1.8  0.776  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626  0.0  0.0  0.000  4.1   6.5  0.626  0.626  2.2  3.0  0.727  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
# [812 rows x 30 columns]

# %%
data.describe(include='all').T.style.background_gradient(cmap = "")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7e258">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e258_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_7e258_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_7e258_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_7e258_level0_col3" class="col_heading level0 col3" >freq</th>
#       <th id="T_7e258_level0_col4" class="col_heading level0 col4" >mean</th>
#       <th id="T_7e258_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_7e258_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_7e258_level0_col7" class="col_heading level0 col7" >25%</th>
#       <th id="T_7e258_level0_col8" class="col_heading level0 col8" >50%</th>
#       <th id="T_7e258_level0_col9" class="col_heading level0 col9" >75%</th>
#       <th id="T_7e258_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e258_level0_row0" class="row_heading level0 row0" >Rk</th>
#       <td id="T_7e258_row0_col0" class="data row0 col0" >812.000000</td>
#       <td id="T_7e258_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_7e258_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_7e258_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_7e258_row0_col4" class="data row0 col4" >304.501232</td>
#       <td id="T_7e258_row0_col5" class="data row0 col5" >172.637333</td>
#       <td id="T_7e258_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_7e258_row0_col7" class="data row0 col7" >158.750000</td>
#       <td id="T_7e258_row0_col8" class="data row0 col8" >300.500000</td>
#       <td id="T_7e258_row0_col9" class="data row0 col9" >459.000000</td>
#       <td id="T_7e258_row0_col10" class="data row0 col10" >605.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row1" class="row_heading level0 row1" >Player</th>
#       <td id="T_7e258_row1_col0" class="data row1 col0" >812</td>
#       <td id="T_7e258_row1_col1" class="data row1 col1" >605</td>
#       <td id="T_7e258_row1_col2" class="data row1 col2" >Greg Monroe</td>
#       <td id="T_7e258_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_7e258_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_7e258_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_7e258_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_7e258_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_7e258_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_7e258_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_7e258_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row2" class="row_heading level0 row2" >Pos</th>
#       <td id="T_7e258_row2_col0" class="data row2 col0" >812</td>
#       <td id="T_7e258_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_7e258_row2_col2" class="data row2 col2" >SG</td>
#       <td id="T_7e258_row2_col3" class="data row2 col3" >199</td>
#       <td id="T_7e258_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_7e258_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_7e258_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_7e258_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_7e258_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_7e258_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_7e258_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_7e258_row3_col0" class="data row3 col0" >812.000000</td>
#       <td id="T_7e258_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_7e258_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_7e258_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_7e258_row3_col4" class="data row3 col4" >26.051724</td>
#       <td id="T_7e258_row3_col5" class="data row3 col5" >4.059640</td>
#       <td id="T_7e258_row3_col6" class="data row3 col6" >19.000000</td>
#       <td id="T_7e258_row3_col7" class="data row3 col7" >23.000000</td>
#       <td id="T_7e258_row3_col8" class="data row3 col8" >25.000000</td>
#       <td id="T_7e258_row3_col9" class="data row3 col9" >29.000000</td>
#       <td id="T_7e258_row3_col10" class="data row3 col10" >41.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row4" class="row_heading level0 row4" >Tm</th>
#       <td id="T_7e258_row4_col0" class="data row4 col0" >812</td>
#       <td id="T_7e258_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_7e258_row4_col2" class="data row4 col2" >TOT</td>
#       <td id="T_7e258_row4_col3" class="data row4 col3" >97</td>
#       <td id="T_7e258_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_7e258_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_7e258_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_7e258_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_7e258_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_7e258_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_7e258_row4_col10" class="data row4 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row5" class="row_heading level0 row5" >G</th>
#       <td id="T_7e258_row5_col0" class="data row5 col0" >812.000000</td>
#       <td id="T_7e258_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_7e258_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_7e258_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_7e258_row5_col4" class="data row5 col4" >36.704433</td>
#       <td id="T_7e258_row5_col5" class="data row5 col5" >25.899099</td>
#       <td id="T_7e258_row5_col6" class="data row5 col6" >1.000000</td>
#       <td id="T_7e258_row5_col7" class="data row5 col7" >12.000000</td>
#       <td id="T_7e258_row5_col8" class="data row5 col8" >36.500000</td>
#       <td id="T_7e258_row5_col9" class="data row5 col9" >61.000000</td>
#       <td id="T_7e258_row5_col10" class="data row5 col10" >82.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row6" class="row_heading level0 row6" >GS</th>
#       <td id="T_7e258_row6_col0" class="data row6 col0" >812.000000</td>
#       <td id="T_7e258_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_7e258_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_7e258_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_7e258_row6_col4" class="data row6 col4" >16.672414</td>
#       <td id="T_7e258_row6_col5" class="data row6 col5" >23.817195</td>
#       <td id="T_7e258_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_7e258_row6_col7" class="data row6 col7" >0.000000</td>
#       <td id="T_7e258_row6_col8" class="data row6 col8" >4.000000</td>
#       <td id="T_7e258_row6_col9" class="data row6 col9" >25.000000</td>
#       <td id="T_7e258_row6_col10" class="data row6 col10" >82.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row7" class="row_heading level0 row7" >MP</th>
#       <td id="T_7e258_row7_col0" class="data row7 col0" >812.000000</td>
#       <td id="T_7e258_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_7e258_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_7e258_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_7e258_row7_col4" class="data row7 col4" >18.265394</td>
#       <td id="T_7e258_row7_col5" class="data row7 col5" >9.648292</td>
#       <td id="T_7e258_row7_col6" class="data row7 col6" >1.000000</td>
#       <td id="T_7e258_row7_col7" class="data row7 col7" >10.500000</td>
#       <td id="T_7e258_row7_col8" class="data row7 col8" >17.500000</td>
#       <td id="T_7e258_row7_col9" class="data row7 col9" >25.725000</td>
#       <td id="T_7e258_row7_col10" class="data row7 col10" >43.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7e258_level0_row8" class="row_heading level0 row8" >FG</th>
#       <td id="T_7e258_row8_col0" class="data row8 col0" >812.000000</td>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      812 non-null    int64
#  1   Player  812 non-null    object
#  2   Pos     812 non-null    object
#  3   Age     812 non-null    int64
#  4   Tm      812 non-null    object
#  5   G       812 non-null    int64
#  6   GS      812 non-null    int64
#  7   MP      812 non-null    float64
#  8   FG      812 non-null    float64
#  9   FGA     812 non-null    float64
#  10  FG%     812 non-null    float64
#  11  3P      812 non-null    float64
#  12  3PA     812 non-null    float64
#  13  3P%     812 non-null    float64
#  14  2P      812 non-null    float64
#  15  2PA     812 non-null    float64
#  16  2P%     812 non-null    float64
#  17  eFG%    812 non-null    float64
#  18  FT      812 non-null    float64
#  19  FTA     812 non-null    float64
#  20  FT%     812 non-null    float64
#  21  ORB     812 non-null    float64
#  22  DRB     812 non-null    float64
#  23  TRB     812 non-null    float64
#  24  AST     812 non-null    float64
#  25  STL     812 non-null    float64
#  26  BLK     812 non-null    float64
#  27  TOV     812 non-null    float64
#  28  PF      812 non-null    float64
#  29  PTS     812 non-null    float64
# dtypes: float64(23), int64(4), object(3)
# memory usage: 190.4+ KB

# %% [markdown]
# ### Missing data

# %%
data.isnull().any()
# Out:
# Rk        False
# Player    False
# Pos       False
# Age       False
# Tm        False
# G         False
# GS        False
# MP        False
# FG        False
# FGA       False
# FG%       False
# 3P        False
# 3PA       False
# 3P%       False
# 2P        False
# 2PA       False
# 2P%       False
# eFG%      False
# FT        False
# FTA       False
# FT%       False
# ORB       False
# DRB       False
# TRB       False
# AST       False
# STL       False
# BLK       False
# TOV       False
# PF        False
# PTS       False
# dtype: bool

# %%
data[data.Pos.isnull()]
# Out:
# Empty DataFrame
# Columns: [Rk, Player, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []

# %%
#In case having missing data, replace it property values
#data.fillna(data.mean())

# %% [markdown]
# ### Correlation

# %%
#Correlation between numerical variables
corr = data.drop(columns=['Pos','Player', 'Tm'])

# %%
corr.corr().T.style.background_gradient(cmap = "hot_r")
# Out:
# <style type="text/css">
# #T_6e1dd_row0_col0, #T_6e1dd_row1_col1, #T_6e1dd_row2_col2, #T_6e1dd_row3_col3, #T_6e1dd_row4_col4, #T_6e1dd_row5_col5, #T_6e1dd_row6_col6, #T_6e1dd_row7_col7, #T_6e1dd_row8_col8, #T_6e1dd_row9_col9, #T_6e1dd_row10_col10, #T_6e1dd_row11_col11, #T_6e1dd_row12_col12, #T_6e1dd_row13_col13, #T_6e1dd_row14_col14, #T_6e1dd_row15_col15, #T_6e1dd_row16_col16, #T_6e1dd_row17_col17, #T_6e1dd_row18_col18, #T_6e1dd_row19_col19, #T_6e1dd_row20_col20, #T_6e1dd_row21_col21, #T_6e1dd_row22_col22, #T_6e1dd_row23_col23, #T_6e1dd_row24_col24, #T_6e1dd_row25_col25, #T_6e1dd_row26_col26 {
#   background-color: #0b0000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row0_col1, #T_6e1dd_row0_col2, #T_6e1dd_row0_col3, #T_6e1dd_row0_col4, #T_6e1dd_row0_col5, #T_6e1dd_row0_col6, #T_6e1dd_row0_col11, #T_6e1dd_row0_col12, #T_6e1dd_row0_col13, #T_6e1dd_row0_col14, #T_6e1dd_row0_col15, #T_6e1dd_row0_col16, #T_6e1dd_row0_col17, #T_6e1dd_row0_col19, #T_6e1dd_row0_col20, #T_6e1dd_row0_col21, #T_6e1dd_row0_col22, #T_6e1dd_row0_col23, #T_6e1dd_row0_col24, #T_6e1dd_row0_col25, #T_6e1dd_row0_col26, #T_6e1dd_row3_col0, #T_6e1dd_row9_col7, #T_6e1dd_row9_col18, #T_6e1dd_row18_col8, #T_6e1dd_row18_col9, #T_6e1dd_row18_col10 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_6e1dd_row0_col7, #T_6e1dd_row2_col0 {
#   background-color: #ffffef;
#   color: #000000;
# }
# #T_6e1dd_row0_col8, #T_6e1dd_row0_col10, #T_6e1dd_row1_col13 {
#   background-color: #ffffc8;
#   color: #000000;
# }
# #T_6e1dd_row0_col9, #T_6e1dd_row8_col13 {
#   background-color: #ffffbc;
#   color: #000000;
# }
# #T_6e1dd_row0_col18, #T_6e1dd_row1_col22, #T_6e1dd_row3_col1, #T_6e1dd_row11_col1, #T_6e1dd_row12_col1, #T_6e1dd_row16_col1, #T_6e1dd_row21_col13 {
#   background-color: #ffffa8;
#   color: #000000;
# }
# #T_6e1dd_row1_col0 {
#   background-color: #ffffd4;
#   color: #000000;
# }
# #T_6e1dd_row1_col2, #T_6e1dd_row7_col21, #T_6e1dd_row9_col23, #T_6e1dd_row15_col1 {
#   background-color: #ffff99;
#   color: #000000;
# }
# #T_6e1dd_row1_col3, #T_6e1dd_row1_col18, #T_6e1dd_row1_col25, #T_6e1dd_row14_col21, #T_6e1dd_row21_col7, #T_6e1dd_row24_col1, #T_6e1dd_row26_col1 {
#   background-color: #ffff81;
#   color: #000000;
# }
# #T_6e1dd_row1_col4, #T_6e1dd_row7_col22, #T_6e1dd_row10_col20, #T_6e1dd_row21_col23, #T_6e1dd_row22_col7, #T_6e1dd_row23_col8 {
#   background-color: #ffff46;
#   color: #000000;
# }
# #T_6e1dd_row1_col5, #T_6e1dd_row9_col1 {
#   background-color: #ffff75;
#   color: #000000;
# }
# #T_6e1dd_row1_col6, #T_6e1dd_row20_col1, #T_6e1dd_row21_col14 {
#   background-color: #ffff7d;
#   color: #000000;
# }
# #T_6e1dd_row1_col7, #T_6e1dd_row2_col1, #T_6e1dd_row10_col18, #T_6e1dd_row10_col23, #T_6e1dd_row13_col0, #T_6e1dd_row13_col21 {
#   background-color: #ffffb4;
#   color: #000000;
# }
# #T_6e1dd_row1_col8, #T_6e1dd_row14_col24, #T_6e1dd_row15_col14, #T_6e1dd_row24_col7 {
#   background-color: #ffff2a;
#   color: #000000;
# }
# #T_6e1dd_row1_col9 {
#   background-color: #ffff32;
#   color: #000000;
# }
# #T_6e1dd_row1_col10 {
#   background-color: #ffff85;
#   color: #000000;
# }
# #T_6e1dd_row1_col11, #T_6e1dd_row7_col9, #T_6e1dd_row10_col0 {
#   background-color: #ffffa0;
#   color: #000000;
# }
# #T_6e1dd_row1_col12, #T_6e1dd_row1_col16, #T_6e1dd_row1_col17, #T_6e1dd_row7_col1 {
#   background-color: #ffffa4;
#   color: #000000;
# }
# #T_6e1dd_row1_col14, #T_6e1dd_row7_col0, #T_6e1dd_row14_col0, #T_6e1dd_row18_col21, #T_6e1dd_row25_col0 {
#   background-color: #ffffb0;
#   color: #000000;
# }
# #T_6e1dd_row1_col15 {
#   background-color: #ffff91;
#   color: #000000;
# }
# #T_6e1dd_row1_col19, #T_6e1dd_row3_col13, #T_6e1dd_row21_col18, #T_6e1dd_row23_col9 {
#   background-color: #ffff42;
#   color: #000000;
# }
# #T_6e1dd_row1_col20, #T_6e1dd_row25_col1 {
#   background-color: #ffff61;
#   color: #000000;
# }
# #T_6e1dd_row1_col21, #T_6e1dd_row23_col21 {
#   background-color: #ffff5a;
#   color: #000000;
# }
# #T_6e1dd_row1_col23, #T_6e1dd_row18_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6e1dd_row1_col24, #T_6e1dd_row14_col1 {
#   background-color: #ffff8d;
#   color: #000000;
# }
# #T_6e1dd_row1_col26, #T_6e1dd_row22_col13 {
#   background-color: #ffff71;
#   color: #000000;
# }
# #T_6e1dd_row2_col3, #T_6e1dd_row4_col16, #T_6e1dd_row5_col21, #T_6e1dd_row19_col18, #T_6e1dd_row20_col4, #T_6e1dd_row23_col20 {
#   background-color: #cf0000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col4, #T_6e1dd_row3_col20, #T_6e1dd_row6_col20, #T_6e1dd_row11_col25, #T_6e1dd_row15_col20, #T_6e1dd_row22_col5, #T_6e1dd_row22_col26 {
#   background-color: #fc0000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col5, #T_6e1dd_row11_col18, #T_6e1dd_row21_col8, #T_6e1dd_row22_col12, #T_6e1dd_row24_col8, #T_6e1dd_row26_col2 {
#   background-color: #ff1f00;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col6, #T_6e1dd_row23_col25 {
#   background-color: #ff2f00;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col7, #T_6e1dd_row13_col5, #T_6e1dd_row20_col9, #T_6e1dd_row23_col14, #T_6e1dd_row26_col7 {
#   background-color: #ffcf00;
#   color: #000000;
# }
# #T_6e1dd_row2_col8, #T_6e1dd_row3_col22, #T_6e1dd_row10_col9, #T_6e1dd_row11_col23, #T_6e1dd_row12_col9 {
#   background-color: #ff4700;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col9, #T_6e1dd_row11_col2, #T_6e1dd_row18_col25 {
#   background-color: #ff4f00;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col10, #T_6e1dd_row7_col23, #T_6e1dd_row7_col25, #T_6e1dd_row14_col18, #T_6e1dd_row15_col23, #T_6e1dd_row17_col16, #T_6e1dd_row17_col25 {
#   background-color: #ffa000;
#   color: #000000;
# }
# #T_6e1dd_row2_col11, #T_6e1dd_row4_col17, #T_6e1dd_row12_col2, #T_6e1dd_row22_col15, #T_6e1dd_row22_col16 {
#   background-color: #ff5600;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col12, #T_6e1dd_row15_col22, #T_6e1dd_row17_col8 {
#   background-color: #ff5e00;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col13, #T_6e1dd_row7_col3, #T_6e1dd_row8_col20, #T_6e1dd_row10_col3, #T_6e1dd_row10_col22, #T_6e1dd_row21_col10 {
#   background-color: #ffe900;
#   color: #000000;
# }
# #T_6e1dd_row2_col14, #T_6e1dd_row4_col14, #T_6e1dd_row12_col17, #T_6e1dd_row13_col11, #T_6e1dd_row18_col26, #T_6e1dd_row20_col14 {
#   background-color: #ffb700;
#   color: #000000;
# }
# #T_6e1dd_row2_col15, #T_6e1dd_row2_col16, #T_6e1dd_row2_col22, #T_6e1dd_row4_col18, #T_6e1dd_row20_col7 {
#   background-color: #ff8800;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col17, #T_6e1dd_row23_col5 {
#   background-color: #ff6900;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col18, #T_6e1dd_row13_col20 {
#   background-color: #ffb000;
#   color: #000000;
# }
# #T_6e1dd_row2_col19, #T_6e1dd_row16_col25, #T_6e1dd_row22_col19, #T_6e1dd_row25_col15 {
#   background-color: #ff3700;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col20, #T_6e1dd_row17_col4, #T_6e1dd_row19_col21, #T_6e1dd_row20_col2 {
#   background-color: #ff4c00;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col21, #T_6e1dd_row9_col25, #T_6e1dd_row13_col18, #T_6e1dd_row19_col7, #T_6e1dd_row25_col14 {
#   background-color: #ffa800;
#   color: #000000;
# }
# #T_6e1dd_row2_col23, #T_6e1dd_row7_col12, #T_6e1dd_row7_col26, #T_6e1dd_row11_col14, #T_6e1dd_row17_col22, #T_6e1dd_row21_col17, #T_6e1dd_row22_col17, #T_6e1dd_row22_col23, #T_6e1dd_row24_col17, #T_6e1dd_row24_col23 {
#   background-color: #ffbf00;
#   color: #000000;
# }
# #T_6e1dd_row2_col24, #T_6e1dd_row5_col17, #T_6e1dd_row11_col7 {
#   background-color: #ff8600;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col25, #T_6e1dd_row12_col23, #T_6e1dd_row20_col22 {
#   background-color: #ff6e00;
#   color: #f1f1f1;
# }
# #T_6e1dd_row2_col26 {
#   background-color: #ff2200;
#   color: #f1f1f1;
# }
# #T_6e1dd_row3_col2, #T_6e1dd_row11_col3, #T_6e1dd_row12_col3, #T_6e1dd_row15_col19, #T_6e1dd_row24_col19 {
#   background-color: #d20000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row3_col4, #T_6e1dd_row4_col9, #T_6e1dd_row24_col15, #T_6e1dd_row24_col16, #T_6e1dd_row26_col19 {
#   background-color: #a80000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row3_col5, #T_6e1dd_row26_col3 {
#   background-color: #b00000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row3_col6 {
#   background-color: #c00000;
#   color: #f1f1f1;
# }
# #T_6e1dd_row3_col7, #T_6e1dd_row3_col14, #T_6e1dd_row8_col14 {
#   background-color: #ffff0f;
#   color: #000000;
# }
# #T_6e1dd_row3_col8, #T_6e1dd_row3_col9, #T_6e1dd_row9_col24, #T_6e1dd_row25_col22 {
#   background-color: #ff2500;
#   color: #f1f1f1;
# }
# #

# %% [markdown]
# ### Preprocessing

# %%
data.describe(include=object)
# Out:
#              Player  Pos   Tm
# count           812  812  812
# unique          605   11   31
# top     Greg Monroe   SG  TOT
# freq              5  199   97

# %%
# Histogram for Positions
data.Pos.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pos'>

# %%
df = data
#Deleting combination of positions
df.drop(df[(df['Pos'] == 'SG-SF') | (df['Pos'] == 'SF-SG') | (df['Pos'] == 'SG-PG') | (df['Pos'] == 'C-PF') | (df['Pos'] == 'PF-SF') | (df['Pos'] == 'PG-SG')].index, inplace=True)
df.Pos.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pos'>

# %%
df.groupby('Pos').size()
# Out:
# Pos
# C     130
# PF    152
# PG    155
# SF    158
# SG    199
# dtype: int64

# %%
#Deleting Ranking and Player columns
df.drop(['Rk','Player'], axis=1, inplace=True)
df
# Out:
#     Pos  Age   Tm   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0     C   22  TOR  73  28  23.6  3.6   8.3  0.439  0.8  2.1  0.359  2.9   6.1  0.468  0.486  1.1  1.8  0.595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1     C   28  MEM  76  75  26.3  2.8   5.1  0.547  0.0  0.0  0.000  2.8   5.0  0.548  0.547  1.4  2.6  0.543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2     C   24  MIA  56  56  32.6  7.3  13.0  0.557  0.0  0.1  0.000  7.3  12.9  0.562  0.557  4.6  6.1  0.753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3    PF   21  MEM  32   0  11.3  1.7   4.1  0.402  0.2  1.5  0.125  1.5   2.6  0.560  0.424  0.6  1.0  0.625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4     C   36  BRK  47  12  22.3  5.4   9.7  0.550  0.3  1.0  0.304  5.1   8.8  0.578  0.566  1.9  2.2  0.873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# ..   ..  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...   ...    ...    ...  ...  ...    ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 807  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  0.7  1.7  0.395  1.9   3.9  0.495  0.524  0.5  1.0  0.481  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
# 808  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  3.1  8.0  0.382  6.3  12.3  0.512  0.536  6.6  7.3  0.904  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
# 809   C   23  MIA  56  12  12.6  2.3   4.4  0.526  0.0  0.2  0.091  2.3   4.2  0.547  0.528  0.7  1.1  0.623  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
# 810   C   29  POR  27   0  13.1  1.9   3.3  0.567  0.0  0.1  0.000  1.9   3.2  0.593  0.567  1.4  1.8  0.776  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 811   C   24  LAC  76  76  24.4  4.1   6.5  0.626  0.0  0.0  0.000  4.1   6.5  0.626  0.626  2.2  3.0  0.727  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
# [794 rows x 28 columns]

# %%
#Watch out for duplicated
duplicate = df[df.duplicated()]
print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []

# %% [markdown]
# ### Univariate analysis depending on label

# %%
#Position:
#C = Center -> Pivot (5)
#PF = Power Forward -> Ala-Pivot (4)
#PG = Point Guard -> Base (1)
#SF = Small Forward -> Aler (3)
#SG = Shooting Guard -> Escolta (2)

groupby_position = df.groupby('Pos')
groupby_position.describe()
# Out:
#        Age                                                    G                                                    GS                                                 MP                                                     FG                                                 FGA                                                FG%                                                    3P                                              3PA                                                 3P%                                                    2P                                              2PA                                              2P%                                                eFG%                                                    FT                                              FTA                                               FT%                                                 ORB                                               DRB                                                 TRB                                               AST                                               STL                                             BLK                                             TOV                                              PF                                               PTS
#      count    mean    std   min   25%   50%    75%   max  count    mean     std  min    25%   50%    75%   max  count    mean     std  min  25%  50%    75%   max  count    mean     std  min    25%    50%    75%   max  count   mean    std  min    25%   50%    75%   max  count   mean    std  min   25%   50%    75%   max  count   mean    std  min    25%    50%    75%    max  count   mean    std  min   25%   50%   75%  max  count   mean    std  min    25%   50%    75%   max  count   mean    std  min    25%    50%    75%    max  count   mean    std  min   25%  50%    75%  max  count   mean    std  min  25%  50%    75%   max  count   mean    std  min    25%    50%    75%  max  count   mean    std  min    25%    50%    75%    max  count   mean    std  min    25%  50%   75%  max  count   mean    std  min  25%   50%    75%   max  count   mean    std  min    25%    50%    75%  max  count   mean    std  min    25%  50%    75%  max  count   mean    std  min    25%   50%    75%   max  count   mean    std  min  25%   50%    75%   max  count   mean    std  min    25%  50%   75%   max  count   mean    std  min  25%  50%    75%  max  count   mean    std  min  25%  50%    75%  max  count   mean    std  min  25%  50%    75%  max  count   mean    std  min    25%  50%    75%  max  count   mean    std  min    25%   50%     75%   max
Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS' ],meanline=False,showmeans=True,return_type='dict', figsize=(20,8))
print("Boxplots")
# Out:
# Boxplots

# %% [markdown]
# ### Histograms of numerical variables

# %%
data.hist(column=['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS' ],  bins=10, figsize=[20,20])
print("Histograms")
# Out:
# Histograms

# %% [markdown]
# ### Bi-variate analysis

# %%
plotting.scatter_matrix(data[['G', 'PTS', 'MP']], figsize=(15,15))
print('Scatter matrixes for correlations betwen numerical variables ')
# Out:
# Scatter matrixes for correlations betwen numerical variables

# %% [markdown]
# ### Label Encoding

# %%
df.groupby('Pos').size() / len(df)
# Out:
# Pos
# C     0.164
# PF    0.191
# PG    0.195
# SF    0.199
# SG    0.251
# dtype: float64

# %%
X = df.drop('Pos', axis=1)
y = df['Pos']

# Label encoding for categoricals
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# list discrete features that have integer dtypes for using MI (Mutual Information)
discrete_features = X.dtypes == int
X
# Out:
#      Age  Tm   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0     22   0  73  28  23.6  3.6   8.3  0.439  0.8  2.1  0.359  2.9   6.1  0.468  0.486  1.1  1.8  0.595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1     28   1  76  75  26.3  2.8   5.1  0.547  0.0  0.0  0.000  2.8   5.0  0.548  0.547  1.4  2.6  0.543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2     24   2  56  56  32.6  7.3  13.0  0.557  0.0  0.1  0.000  7.3  12.9  0.562  0.557  4.6  6.1  0.753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3     21   1  32   0  11.3  1.7   4.1  0.402  0.2  1.5  0.125  1.5   2.6  0.560  0.424  0.6  1.0  0.625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4     36   3  47  12  22.3  5.4   9.7  0.550  0.3  1.0  0.304  5.1   8.8  0.578  0.566  1.9  2.2  0.873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# ..   ...  ..  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...   ...    ...    ...  ...  ...    ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 807   33   0  26   0  18.3  2.6   5.5  0.465  0.7  1.7  0.395  1.9   3.9  0.495  0.524  0.5  1.0  0.481  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
# 808   23  20  76  76  34.9  9.4  20.3  0.460  3.1  8.0  0.382  6.3  12.3  0.512  0.536  6.6  7.3  0.904  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
# 809   23   2  56  12  12.6  2.3   4.4  0.526  0.0  0.2  0.091  2.3   4.2  0.547  0.528  0.7  1.1  0.623  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
# 810   29  29  27   0  13.1  1.9   3.3  0.567  0.0  0.1  0.000  1.9   3.2  0.593  0.567  1.4  1.8  0.776  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 811   24  24  76  76  24.4  4.1   6.5  0.626  0.0  0.0  0.000  4.1   6.5  0.626  0.626  2.2  3.0  0.727  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
# [794 rows x 27 columns]

# %% [markdown]
# ### Features selection

# %%
def scoring(X, y, discrete_features):
    score = mutual_info_classif(X, y, discrete_features=discrete_features)
    score = pandas.Series(score, name="Scores", index=X.columns)
    score = score.sort_values(ascending=False)
    return score

scores = scoring(X, y, discrete_features)
scores
# Out:
# ORB     2.400e-01
# 3PA     1.545e-01
# FG%     1.532e-01
# eFG%    1.522e-01
# TRB     1.336e-01
# 2P%     1.289e-01
# BLK     1.102e-01
# AST     9.328e-02
# 3P      8.310e-02
# Age     6.327e-02
# FT      5.266e-02
# DRB     4.940e-02
# STL     4.385e-02
# 2P      4.312e-02
# FT%     4.211e-02
# FTA     3.871e-02
# 2PA     3.623e-02
# 3P%     2.534e-02
# FGA     1.921e-02
# PF      1.004e-02
# FG      3.280e-03
# MP      7.779e-04
# GS      0.000e+00
# G       0.000e+00
# TOV     0.000e+00
# Tm      0.000e+00
# PTS     0.000e+00
# Name: Scores, dtype: float64

# %%
def drop_uninformative(df, scores):
    return df.loc[:, scores > 0.05]

X = drop_uninformative(df, scores)
X
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[45], line 4
#       1 def drop_uninformative(df, scores):
#       2     return df.loc[:, scores > 0.05]
# ----> 4 X = drop_uninformative(df, scores)
#       5 X
#
# Cell In[45], line 2, in drop_uninformative(df, scores)
#       1 def drop_uninformative(df, scores):
# ----> 2     return df.loc[:, scores > 0.05]
#
# File ~\MD\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\MD\lib\site-packages\pandas\core\indexing.py:1289, in _LocIndexer._getitem_tuple(self, tup)
#    1286 if self._multi_take_opportunity(tup):
#    1287     return self._multi_take(tup)
# -> 1289 return self._getitem_tuple_same_dim(tup)
#
# File ~\MD\lib\site-packages\pandas\core\indexing.py:955, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     952 if com.is_null_slice(key):
#     953     continue
# --> 955 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     956 # We should never have retval.ndim < self.ndim, as that should
#     957 #  be handled by the _getitem_lowerdim call above.
#     958 assert retval.ndim == self.ndim
#
# File ~\MD\lib\site-packages\pandas\core\indexing.py:1325, in _LocIndexer._getitem_axis(self, key, axis)
#    1323     return self._get_slice_axis(key, axis=axis)
#    1324 elif com.is_bool_indexer(key):
# -> 1325     return self._getbool_axis(key, axis=axis)
#    1326 elif is_list_like_indexer(key):
#    1327     # an iterable multi-selection
#    1328     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~\MD\lib\site-packages\pandas\core\indexing.py:1121, in _LocationIndexer._getbool_axis(self, key, axis)
#    1117 @final
#    1118 def _getbool_axis(self, key, axis: AxisInt):
#    1119     # caller is responsible for ensuring non-None axis
#    1120     labels = self.obj._get_axis(axis)
# -> 1121     key = check_bool_indexer(labels, key)
#    1122     inds = key.nonzero()[0]
#    1123     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~\MD\lib\site-packages\pandas\core\indexing.py:2499, in check_bool_indexer(index, key)
#    2497 indexer = result.index.get_indexer_for(index)
#    2498 if -1 in indexer:
# -> 2499     raise IndexingError(
#    2500         "Unalignable boolean Series provided as "
#    2501         "indexer (index of the boolean Series and of "
#    2502         "the indexed object do not match)."
#    2503     )
#    2505 result = result.take(indexer)
#    2507 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
